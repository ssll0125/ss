# %% [markdown]
# # Pharmacokinetics of Perfluoroalkyl acids (PFAAs)
#
# PFAAs are chemicals that are used for the catalysis of various chemical processes including polymerization and oligomerization. Domestically they are used by the automotive, aviation, electronic, packaging and textile industries. They are also actively used for biomaterial and household product development. They are present in biocides [Sznajder-Katarzyńska., 2019](https://www.hindawi.com/journals/jchem/2019/2717528/). Especially in the field of biomedical engineering, beginning from the preparation of gels to medical devices, perfluoroalkyl components and fluorocarbons are used [Krafft et al., 1998](https://pdf.sciencedirectassets.com/272115/1-s2.0-S0300908400X00569/1-s2.0-S0300908400800164/main.pdf?).
#
# PFAAs are a significant environmental concern due to their ability to accumulate in humans and animals. However, there is significant debate ongoing about the risk of outright bans on PFAAs, specifically for the biomedical community (see [this](https://nap.nationalacademies.org/catalog/26156/guidance-on-pfas-exposure-testing-and-clinical-follow-up) report by the National Academies, and [this](https://www.govinfo.gov/content/pkg/FR-2022-07-13/pdf/2022-14862.pdf) Request for Information from the White House).
#
# In this ongoing effort to understand PFAAs and their impact on our bodies, one approach to study and predict the levels of PFAAs in humans is through the use of Pharmacokinetic models.
#
# Pharmacokinetics is a description of the concentration changes of a chemical or a drug in the body over time. Pharmacokinetics are most commonly used to describe the changes in concentrations in the blood, but there are very complex models out there (called Physiology Based Pharmacokinetic or PBPK models for those that are interested) that also account for concentration changes in various organs and tissues.
#
# In this project we will only consider concentrations in blood.

# %% [markdown]
# In this project, you will develop and use a simple pharmacokinetic model to describe the concentration of a PFAA in human blood. Through the various tasks, you will add increasing complexity and use your model to answer fundamental questions about the accumulation of PFAAs in blood.
#
# - How long does it take for PFAAs to reach toxic levels?
# - What are the predicted steady state levels in different individuals?
#
# This project is loosely based on the work by [Verner et al., 2016](https://pubs.acs.org/doi/10.1021/acs.est.5b04399) who evaluated the accumulation of these chemicals in mothers and newborn children.

# %% [markdown]
# There are a number of processes that can affect the pharmacokinetics of a chemical. Below is a non-exhaustive list that we will consider within this project:
#
# 1. **Exposure or dose**. This is the 'source' of the chemical. It can be a one-time exposure (like taking a pill) or it can be continuous (like from some environmental source in your house).
#
# 2. **Excretion**. If the chemical can be effectively removed from our bodies (e.g. through the kidneys). This represents a 'loss' of the chemical.
#
# 3. **Metabolism**. If the chemical can be converted into something else, this also represents a 'loss'. These are often enzymatic reactions where the chemical is converted to another substance that can then be excreted or used in a different way.

# %% [markdown]
# ## Task 0: Planning
# Please respond to these questions and provide evidence of your planning process:
#
# - Please lay out a tentative plan, including a list of activities you have to perform for approaching the solution to this project (i.e., breakdown of work)
#
# To start, I will need to draw a diagram for 1a. Then, using the information provided, I will derive a mass balance equation and solve for time to get values for the time it takes for men and women to reach the toxic threshold concentration. Next, I will solve for these values again using a numerical approach (Euler's Method) and discuss my results. For task 2, I will follow a similar procedure but this time including the reactions and presence of a metabolite E. I will derive another equation, but this time only solve for t values numerically. Finally, I will discuss my takeaways from the project.

# %% [markdown]
# - What are the thermodynamics/scientific concepts you will need? Please elaborate on how it will be useful or applied to the problem.
#
# The first thermodynamic skill I will need is the mass balance equation. The mass balance equation is the foundation of this entire project and I will need to utilize it correctly to succeed. I will also need to understand mathematical concepts such as separation of variables, integrals, and Euler's method to get results using my mass balance equation.

# %% [markdown]
# - Draw or insert a flow chart or write down the algorithm representing the computational solution of your project (it is ok if this is not correct or very detailed; this is a preliminary plan for how to solve)
#
# For the computational portions of the project, I will take my mass balance equation and use separation of variables to prepare for integration. Once mass and time are separated, I will integrate and solve for t. Once I have an equation for t, I can plug in the values I am given and compute.

# %% [markdown]
# ## Task 1: Accumulation without metabolism or excretion

# %% [markdown]
# In this task you will consider a PFAA that accumulates in blood and that is excreted at a fixed rate.
#
# In toxicology, the concentration at which toxicity first appears is known as the threshold concentration. It is not currently clear what the threshold concentration for adverse effects of PFAAs [are](https://portal.ct.gov/-/media/DEEP/PFASTaskForce/HHCBarlowBoydKempHoppeParr2019PFASToxicologypdf.pdf). For this project, we will assume that a concentration of PFAA in the blood above 80 ng/L is toxic.
#
# For this part assume that the exposure is constant from an environmental source like water, and that the exposure rate is $k_e = 90$ ng/day.
#
# Also assume that the rate constant of excretion of the PFAA is $k_{exc} =  0.2 $ per day.

# %% [markdown]
# ### Task 1a: Draw the system
#
# In the box below (or attached as a separate pdf) please insert a diagram of the system including all inflows and outflows and reactions.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Task 1b: Write the differential mass balance equation
#
# In the text cell below derive and simplify the differential mass balance for this system.
#
# You can find instructions for typing equations in Google Colaboratories (along with a cheat sheet) at [this](https://colab.research.google.com/github/bebi103a/bebi103a.github.io/blob/master/lessons/00/intro_to_latex.ipynb) website.

# %% [markdown]
# #### Insert your equations here
#
# $\frac{dM}{dt} = $ $k_{e} - k_{exc} \cdot M$
#
# where $M$ represents the mass of PFAA in the blood (in ng).

# %% [markdown]
# ### Task 1c: Time to reach toxic threshold concentration - Analytical approach
#
# In this task, use your differential mass balance that you derived above to determine **how long it will take before the PFAA concentration reaches a toxic threshold** in an average American male that
# - has a total blood volume of 5.5 liters, and
# - has zero PFAA in his system at the start of his exposure.
#
# We assume for this project that the PFAA will only accumulate in the blood, so we do NOT consider the volume of other tissues and organs.
#
# In the text cell below, solve the differential mass balance equation analytically, and use the analytical solution to answer the question.

# %% [markdown]
# Step 1: Starting Mass Balance Equation
#
# $ \frac{dM}{dt} = k_e - k_{exc} \cdot M $
#
# Step 2: Separation of Variables
#
# $ \frac{dM}{(k_e - k_{exc} \cdot M)} = dt$
#
# Step 3: Integrate
#
# $ -\frac{1}{k_{exc}}(\ln(k_e - k_{exc} \cdot M) - \ln(k_e)) = t$
#
# Step 4: Plug in values
#
# $ -\frac{1}{0.2}(\ln(90 - 0.2 \cdot (80 \cdot 5.5)) - \ln(90)) = t$
#
# Final result:
#
# $ t = 19.0333 $ seconds

# %% [markdown]
# ### Task 1d: Time to reach toxic threshold concentration - Analytical approach
#
# This task is similar to Task 1c. Here, use your analytical solution that you derived above to determine how long it will take before the PFAA concentration reaches a toxic threshold **in an average American female** that:
# - has a total blood volume of 4.5 liters, and
# - has zero PFAA in her system at the start of her exposure.
#
# Assume that the woman's rate of exposure ($k_e$) is also 90 ng/day and the rate constant of excretion is also 0.2 /day.
#
# Type your answers in the text cell below.

# %% [markdown]
# Step 1: Starting Mass Balance Equation
#
# $ \frac{dM}{dt} = k_e - k_{exc} \cdot M $
#
# Step 2: Separation of Variables
#
# $ \frac{dM}{(k_e - k_{exc} \cdot M)} = dt$
#
# Step 3: Integrate
#
# $ -\frac{1}{k_{exc}}(\ln(k_e - k_{exc} \cdot M) - \ln(k_e)) = t$
#
# Step 4: Plug in values
#
# $ -\frac{1}{0.2}(\ln(90 - 0.2 \cdot (80 \cdot 4.5)) - \ln(90)) = t$
#
# Final result:
#
# $ t = 8.0472 $ seconds

# %% [markdown]
# ### Task 1e: Impact of body size on chemical accumulation
#
# Based on your solutions to Tasks 1c and 1d, what impact does body size (blood volume in our case) have on the risk of someone reaching toxic threshold concentrations? Assuming that the exposure is at a constant rate (ng chemical per day).

# %% [markdown]
# Claim: Under the current conditions, the blood volume of the person is directly proportional to the risk of someone reaching toxic threshold concentrations
#
# Evidence: The calculations show that as the blood volume went from 5.5 liters to 4.5 liters, the time it takes to reach toxic threshold concentrations drops from roughly 19 seconds to roughly 8 seconds.
#
# Reasoning: The time decreasing as the blood volume decreases indicates that a smaller body means a quicker time to reach toxic threshold concentrations, meaning the risk goes up as the blood volume and time goes down.

# %% [markdown]
# ### Task 1f: Numerical solution of mass balance equation
#
# In this task, you will **numerically** solve the differential mass balance equation that you derived in Task 1b. More specifically your code should do the following:
#
# - Solve the differential equation numerically for **both the man and woman from Tasks 1c and 1d**.
# - Plot the dynamics of the **concentration (ng per L)** of PFAA for each of these individuals.
#
#
# Hint: **You can use the pseudocode and code examples from your class notes as scaffolds or outlines to build from.**
#
# ****
#
# In the text cell below, enter the pseudocode for how you plan to numerically solve the equation

# %% [markdown]
# 1. Define a function relating concentration with time
# 2. Define initial conditions for concentration and time
# 3. Define step size (h) and number of steps (n)
# 4. Create arrays the size of n to hold values for concentration and time
# 5. Set the first value of each array equal to the initial condition of the variable
# 6. for$ j$ from $1$ to $n$ do:
# >a) $C_j = C_{j-1} + f(t_{j-1},C_{j-1})*h$
# >>b) $t_j = t_{j-1} + h$
# 7. Plot $C$ vs $t$

# %% [markdown]
# #### Enter your code here
#
# In the code cell below, write your code to achieve the goals that we outlined above.

# %%
# Import libraries   
# %matplotlib inline
import matplotlib.pyplot as plt

def dCdt_man(C): #Concentration function for man
  V_man = 5.5 #Blood volume of average man's body in liters
  k_e = 90 #Exposure rate in ng/day
  k_exc = 0.2 #rate of excretion in 1/day

  dCdt_man = (k_e/V_man) - k_exc * C  #Change in concentration over time for man

  return dCdt_man; 

def dCdt_woman(C): #Concentration function for woman
  V_woman = 4.5 #Blood volume of average woman's body in liters
  k_e = 90 #Exposure rate in ng/day
  k_exc = 0.2 #rate of excretion in 1/day
  dCdt_woman = (k_e/V_woman) - k_exc * C  #Change in concentration over time for woman

  return dCdt_woman

# Initial conditions
C0 = 0
t0 = 0
# Total length of time to solve over 
tf = 30
# Define the size of the timesteps that you want 
del_t = .1
# number of steps needed
num_steps = int((tf - t0)/del_t)

# Arrays for both concentrations and time
Cman_mesh = [0]*(num_steps + 1)
Cwoman_mesh = [0]*(num_steps + 1)
time_mesh = [0]*(num_steps + 1)

# Setting first index of array equal to initial conditions
Cman_mesh[0] = C0
Cwoman_mesh[0] = C0
time_mesh[0] = t0

# A foor loop that will calculate the concentration for both men and woman at the current time step and add it to the arrays
for j in range(num_steps):         # repeats until an index (j) reaches the value of num_steps

    Cman_mesh[j+1] = Cman_mesh[j] + dCdt_man(Cman_mesh[j])*del_t   
    Cwoman_mesh[j+1] = Cwoman_mesh[j] + dCdt_woman(Cwoman_mesh[j])*del_t    
    # update the time_mesh by adding del_t to the previous timestep
    time_mesh[j+1] = time_mesh[j] + del_t

# Plot both concentrations as a function of time
plt.plot(time_mesh,Cman_mesh,color='b') #function for man
plt.plot(time_mesh,Cwoman_mesh,color='r') #function for woman
plt.title('Concentration in Body Over Time') #plot title
plt.xlabel('Time (sec)') # x-axis (time in seconds)
plt.ylabel('Concentration (ng/L)') # y-axis (concentraion in ng/L)
plt.legend(['Man','Woman'])
plt.grid()

# %% [markdown]
# #### Interpret your graph
#
# Based on the graph that you generated answer the following questions:
#
# - Based on the graph, approximately how long would it take the male and female person to reach the toxic threshold?
#
# - What attribute of the graph are you using to make this claim?
#
# - Do your numerical results agree with your analytical results from Tasks 1c and 1d? Is this result expected, and why?

# %% [markdown]
# 1. According to the graph obtained from my code, it would take approximately 18-19 seconds for a man to reach toxic threshold concentration levels and approximately 7.5-8 seconds for a woman to reach toxic threshold concentration levels.
#
# 2. You can make these estimations by observing the x value for each function at the 80 ng/L mark on the y axis of the graph, since 80 ng/L is the toxic threshold concnetration.
#
# 3. Yes, my results are roughly the same from my analytical results. This is expected since both methods are solving for a relationship between concentration and time, meaning they both will achieve the same results.

# %% [markdown]
# ## Task 2: Accumulation with excretion and metabolism

# %% [markdown]
# In this task, we consider the same system we had in Task 1. However, in this task, we add the ability of the PFAA to chemically react with a certain metabolite ($E$) and in this process be converted into an inert chemical that can be effectively removed from the body. You do not have to do any calculations for the product of this reaction.
#
# The reaction between the PFAA and the metabolite $E$ occurs with a rate constant $k_{rxn}$ which has a value of $0.02 \frac{L}{ng.day}$. This reaction is irreversible.
#
# The metabolite $E$ is initially present at a total mass of 100 ng, and it is produced at a rate constant $k_p = 10 $ ng/day. Finally, the metabolite $E$ degrades with a rate constant $k_{deg} = 0.1$ /day.

# %% [markdown]
# ### Task 2a: Draw the system
#
# In the box below (or attached as a separate pdf) please insert a diagram of the system including all inflows and outflows and reactions.
#
# Hint: Remember, since we have two components in this system now (the PFAA and the metabolite), you need to specify which component each of the ins/outs/generation/consumption terms are affecting.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Task 2b: Write the differential mass balance equation
#
# In the text cell below derive and simplify the the differential mass balance for this system. Write the balance equation for both the PFAA and the metabolite.
#
# You can find instructions for typing equations (along with a cheat sheet) at [this](https://colab.research.google.com/github/bebi103a/bebi103a.github.io/blob/master/lessons/00/intro_to_latex.ipynb) website.

# %% [markdown]
# $\frac{dM}{dt} = k_e - k_{exc} \cdot M_{PFAA} - (k_{rxn} \cdot C_{PFAA} \cdot C_{metabolite} \cdot V)$
#
# $\frac{dE}{dt} = k_p - k_{deg} \cdot M_{metabolite} - (k_{rxn} \cdot C_{PFAA} \cdot C_{metabolite} \cdot V)$
#
# where $M$ represents the mass of PFAA in the blood (in ng), and $E$ represents the mass of the metabolite in the blood (in ng).
#
# Hint: Remember to check your units!!

# %% [markdown]
# ### Task 2c: Numerical solution of mass balance equation
#
# In this task, you will **numerically** solve the differential mass balance equations that you derived in Task 2b. More specifically your code should do the following:
#
# - Solve both differential equations numerically for **both the man and woman from Tasks 1c and 1d**.
# - Plot the dynamics of the **concentration (ng per L)** of PFAA for each of these individuals.
# - Plot the dynamics of the **concentration (ng per L)** of the metabolite $E$ for each of these individuals.
#
#
# Hint: You can use the pseudocode and code examples from your class notes, and from Task 1, as scaffolds or outlines to build from. Be careful about parameters though, make sure the correct blood volumes are used in all parts of the equations.
#
# ****
#
# In the text cell below, enter the pseudocode for how you plan to numerically solve the equation

# %% [markdown]
# #### Enter your pseudo code as a bullet list here:
#
# 1. Define a function relating concentration with time for PFAA
# 2. Define a function relating concentration with time for E
# 3. Define initial conditions for both masses and time
# 3. Define step size (h) and number of steps (n)
# 4. Create arrays the size of n to hold values for both masses and time
# 5. Set the first value of each array equal to the initial condition of the variable
# 6. for$ j$ from $1$ to $n$ do:
# >a) $C_j = C_{j-1} + f(t_{j-1},C_{j-1})*h$ (PFAA)
# >>b) $C_j = C_{j-1} + f(t_{j-1},C_{j-1})*h$ (metabolite E)
# >>>c) $t_j = t_{j-1} + h$
# 7. Plot $C$ vs $t$

# %% [markdown]
# #### Enter your code here
#
# In the code cell below, write your code to achieve the goals that we outlined above.

# %%
# Import libraries   
# %matplotlib inline
import matplotlib.pyplot as plt

def dCdt_man(C_p,C_e): #Concentration of PFAA function for man
  V_man = 5.5 #Blood volume of average man's body in liters
  k_e = 90 #Exposure rate in ng/day
  k_exc = 0.2 #rate of excretion in 1/day
  k_rxn = 0.02 #rate of reaction between PFAA and metabolite

  dCdt_man = (k_e/V_man) - (k_exc * C_p) - (k_rxn * C_p * C_e)  #Change in concentration over time for man

  return dCdt_man; 

def dCdt_woman(C_p,C_e): #Concentration of PFAA function for man
  V_woman = 4.5 #Blood volume of average man's body in liters
  k_e = 90 #Exposure rate in ng/day
  k_exc = 0.2 #rate of excretion in 1/day
  k_rxn = 0.02 #rate of reaction between PFAA and metabolite

  dCdt_woman = (k_e/V_woman) - (k_exc * C_p) - (k_rxn * C_p * C_e)  #Change in concentration over time for man

  return dCdt_woman; 

def dEdt_man(C_p,C_e):
  V_man = 5.5
  k_rxn = 0.02
  k_p = 10
  k_deg = 0.1

  dEdt_man = (k_p/V_man) - (k_deg * C_e) - (k_rxn * C_p * C_e)

  return dEdt_man

def dEdt_woman(C_p,C_e):
  V_woman = 4.5
  k_rxn = 0.02
  k_p = 10
  k_deg = 0.1

  dEdt_woman = (k_p/V_woman) - (k_deg * C_e) - (k_rxn * C_p * C_e)

  return dEdt_woman

# Initial conditions
C0_p = 0
C0_e_man = 100/5.5
C0_e_woman = 100/4.5
t0 = 0
# Total length of time to solve over 
tf = 30
# Define the size of the timesteps that you want 
del_t = .1
# number of steps needed
num_steps = int((tf - t0)/del_t)

# Arrays for both concentrations and time
Cman_mesh_p = [0]*(num_steps + 1)
Cwoman_mesh_p = [0]*(num_steps + 1)
Cman_mesh_e = [0]*(num_steps + 1)
Cwoman_mesh_e = [0]*(num_steps + 1)
time_mesh = [0]*(num_steps + 1)

# Setting first index of arrays equal to initial conditions
Cman_mesh_p[0] = C0_p
Cwoman_mesh_p[0] = C0_p
Cman_mesh_e[0] = C0_e_man
Cwoman_mesh_e[0] = C0_e_woman
time_mesh[0] = t0

# A foor loop that will calculate the concentration for both men and woman at the current time step and add it to the arrays
for j in range(num_steps):         # repeats until an index (j) reaches the value of num_steps

    Cman_mesh_p[j+1] = Cman_mesh_p[j] + dCdt_man(Cman_mesh_p[j],Cman_mesh_e[j])*del_t   
    Cwoman_mesh_p[j+1] = Cwoman_mesh_p[j] + dCdt_woman(Cwoman_mesh_p[j],Cwoman_mesh_e[j])*del_t 
    Cman_mesh_e[j+1] = Cman_mesh_e[j] + dEdt_man(Cman_mesh_p[j],Cman_mesh_e[j])*del_t    
    Cwoman_mesh_e[j+1] = Cwoman_mesh_e[j] + dEdt_woman(Cwoman_mesh_p[j],Cwoman_mesh_e[j])*del_t  
    # update the time_mesh by adding del_t to the previous timestep
    time_mesh[j+1] = time_mesh[j] + del_t

# Plot both concentrations as a function of time

plt.figure()
plt.plot(time_mesh,Cman_mesh_p,color='b') #function for man for PFAA
plt.plot(time_mesh,Cwoman_mesh_p,color='r') #function for woman for PFAA
plt.title('Concentration of PFAA in Body Over Time') #plot title
plt.xlabel('Time (sec)') # x-axis (time in seconds)
plt.ylabel('Concentration (ng/L)') # y-axis (concentraion in ng/L)
plt.legend(['Man','Woman'])
plt.grid()

plt.figure()
plt.plot(time_mesh,Cman_mesh_e,color='g') #function for man for E
plt.plot(time_mesh,Cwoman_mesh_e,color='r') #function for woman for E
plt.title('Concentration of E in Body Over Time') #plot title
plt.xlabel('Time (sec)') # x-axis (time in seconds)
plt.ylabel('Concentration (ng/L)') # y-axis (concentraion in ng/L)
plt.legend(['Man','Woman'])
plt.grid()

plt.show()

# %% [markdown]
# ### Task 2d: Interpreting the numerical results
#
# Based on your solutions in Task 2c answer the following questions using the argumentation framework:

# %% [markdown]
# 1. How long would it take the male and female person to reach the toxic threshold if we include the possible reaction with metabolite E?
#
# Claim: With the addition of the metabolite E, the time it takes to reach a toxic concentration for women is 12.5 seconds, whereas men will never reach a toxic concentration.
#
# Evidence: The graph shows that the x value that corresponds to the 80 ng/L concentration mark is 12.5 seconds. For men, the function begins to flatten before it reaches 80 ng/L.
#
# Reasoning: Using the mass balance equation and the graph creating using its function, we can determine the time taken to reach toxic concentrations for both men and women.

# %% [markdown]
# 2. by comparing your results in Task 1f vs. your results in Task 2c. How does the reaction with the metabolite $E$ affect the risk of both people to reach the toxic concentration threshold?
#
#
# Claim: The metabolite decreases the risk of reaching toxic concentrations for women and completely nullifies the risk for men.
#
# Evidence: Taking the graphs from before and after the metabolite was added, we can see that the graph with the metabolite added progresses at a much slower pace than the graph without the metabolite. We can also see that for men, the curve with the metabolite never hits toxic concentrations, whereas without the metabolite it does.
#
# Reasoning: Using the information from the graphs, we can see that the addition of a metabolite slows down the rate at which concentration increases over time. We can also see that the addition of a metabolite completely drops the risk of reaching the toxic concentration threshold for men.

# %% [markdown]
# ## Task 3: Reflection
#
# Please answer the following questions:
#
# - What skills did you have to develop to accomplish this project?
#
# - What aspects of this project were the most beneficial for your learning?
#
# - What challenges did you encounter in completing the project?
#
# - How did you overcome the challenges or remedy the problems encountered?
#
# - What time management strategies did you implement for organizing the tasks to be completed for this project and how well did they work for you?

# %% [markdown]
# 1. To complete this project, I had to work on my analytical skills to ensure that all units matched within my mass balance equations. I also had to brush up on my python coding skills to develop code that would solve these mass balance equations numerically and plot them.
#
# 2. The absolute most beneficial part of this project for me was developing mass balance equations using information given. This was something I was struggling with in class and on our first homework assignment, so getting good practice with it was very helpful for me. Being exposed to more coding was also good practice and will definitely prove to be useful in future assignments.
#
# 3. As stated before, I initially struggled create the mass balance equation for both 1b and 2b. I also had some difficulties with the code in 2c, as it took me a few tries to get it running properly.
#
# 4. To figure out how to get my mass balance equations, I both went to office hours and communicated with the professor via email for any suggestions they could give me. The main piece of advice I was given was to think in terms of units rather than variables and simply match units so every checks out. This helped a lot, and I was able to derive all of my equations with this advice. As for the code, I was able to solve my issues by simply going through it multiple times to find any errors.
#
# 5. The main strategy I used was outlining everything that had to be done before even starting the project. After doing so, I was able to get a good picture on how long each section would take me and which ones I might struggle with. The ones I thought were more difficult I did first so I would have time to ask questions in office hours or via email.
